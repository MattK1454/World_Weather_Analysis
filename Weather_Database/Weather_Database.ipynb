# %%
# Import dependencies
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key

# %%
# Establish base API url for openweather API.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lats_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If city is unique, then add it to the cities list.
    if city not in cities:
        cities.append(city)
    
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Create an empty list to hold the weather data.
city_data=[]

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint url with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description =  city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the Data Loading is complete.
print("----------------------------")
print("Data Retieval Complete      ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | agirish
# Processing Record 4 of Set 1 | faanui
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | najran
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | san cristobal
# Processing Record 9 of Set 1 | aranos
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | ormara
# Processing Record 17 of Set 1 | aklavik
# Processing Record 18 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | vila velha
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | saint-philippe
# Processing Record 22 of Set 1 | muyezerskiy
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | cherskiy
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | olga
# Processing Record 30 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | rio gallegos
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | nemuro
# Processing Record 35 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 1 | atambua
# Processing Record 37 of Set 1 | upernavik
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | vanimo
# Processing Record 41 of Set 1 | buzmeyin
# Processing Record 42 of Set 1 | senanga
# Processing Record 43 of Set 1 | margate
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 45 of Set 1 | wilmington
# Processing Record 46 of Set 1 | biak
# Processing Record 47 of Set 1 | ornskoldsvik
# Processing Record 48 of Set 1 | padang
# Processing Record 49 of Set 1 | qafqafa
# Processing Record 50 of Set 1 | pungesti
# Processing Record 1 of Set 2 | nortelandia
# Processing Record 2 of Set 2 | tayu
# Processing Record 3 of Set 2 | vao
# Processing Record 4 of Set 2 | rocha
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | bethel
# Processing Record 7 of Set 2 | makushino
# Processing Record 8 of Set 2 | port-gentil
# Processing Record 9 of Set 2 | hermanus
# Processing Record 10 of Set 2 | guhagar
# Processing Record 11 of Set 2 | constitucion
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | pacifica
# Processing Record 14 of Set 2 | glarus
# Processing Record 15 of Set 2 | lanzhou
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | port hawkesbury
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | mezhdurechensk
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | clarence town
# Processing Record 22 of Set 2 | itaqui
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | tanete
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | vila franca do campo
# Processing Record 27 of Set 2 | harper
# Processing Record 28 of Set 2 | maniitsoq
# Processing Record 29 of Set 2 | novo horizonte
# Processing Record 30 of Set 2 | nome
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 2 | mehamn
# Processing Record 34 of Set 2 | richards bay
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | opuwo
# Processing Record 38 of Set 2 | ancud
# Processing Record 39 of Set 2 | miraflores
# Processing Record 40 of Set 2 | guaruja
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | iranshahr
# Processing Record 43 of Set 2 | soyo
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | broome
# Processing Record 46 of Set 2 | la asuncion
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 49 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 2 | lasa
# Processing Record 1 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | iqaluit
# Processing Record 4 of Set 3 | chuy
# Processing Record 5 of Set 3 | popondetta
# Processing Record 6 of Set 3 | ushuaia
# Processing Record 7 of Set 3 | nishihara
# Processing Record 8 of Set 3 | pierre
# Processing Record 9 of Set 3 | shingu
# Processing Record 10 of Set 3 | preston
# Processing Record 11 of Set 3 | thinadhoo
# Processing Record 12 of Set 3 | suntar
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | pouebo
# Processing Record 15 of Set 3 | pitimbu
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | dikson
# Processing Record 19 of Set 3 | uporovo
# Processing Record 20 of Set 3 | shenjiamen
# Processing Record 21 of Set 3 | luwuk
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | manokwari
# Processing Record 24 of Set 3 | sambava
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | hualmay
# Processing Record 27 of Set 3 | zarand
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | bonavista
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | ribeira grande
# Processing Record 32 of Set 3 | zhigansk
# Processing Record 33 of Set 3 | longyearbyen
# Processing Record 34 of Set 3 | tessalit
# Processing Record 35 of Set 3 | saint anthony
# Processing Record 36 of Set 3 | kashan
# Processing Record 37 of Set 3 | shelton
# Processing Record 38 of Set 3 | huarmey
# Processing Record 39 of Set 3 | sidi ali
# Processing Record 40 of Set 3 | barrow
# Processing Record 41 of Set 3 | vestmannaeyjar
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | provideniya
# Processing Record 44 of Set 3 | upington
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | khatanga
# Processing Record 47 of Set 3 | kaabong
# Processing Record 48 of Set 3 | paraguacu paulista
# Processing Record 49 of Set 3 | verdalsora
# City not found. Skipping...
# Processing Record 50 of Set 3 | jinchang
# Processing Record 1 of Set 4 | shache
# Processing Record 2 of Set 4 | ponta delgada
# Processing Record 3 of Set 4 | sovetskiy
# Processing Record 4 of Set 4 | shchors
# Processing Record 5 of Set 4 | waipawa
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | fukue
# Processing Record 8 of Set 4 | ojitlan
# City not found. Skipping...
# Processing Record 9 of Set 4 | klaipeda
# Processing Record 10 of Set 4 | clyde river
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | bahir dar
# Processing Record 16 of Set 4 | maniwaki
# Processing Record 17 of Set 4 | cap-aux-meules
# Processing Record 18 of Set 4 | kudahuvadhoo
# Processing Record 19 of Set 4 | fuxin
# Processing Record 20 of Set 4 | beringovskiy
# Processing Record 21 of Set 4 | marzuq
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | butaritari
# Processing Record 24 of Set 4 | oceanside
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | mahebourg
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | sitka
# Processing Record 29 of Set 4 | general roca
# Processing Record 30 of Set 4 | grand gaube
# Processing Record 31 of Set 4 | kaeo
# Processing Record 32 of Set 4 | atasu
# Processing Record 33 of Set 4 | namibe
# Processing Record 34 of Set 4 | shimoda
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | arraial do cabo
# Processing Record 37 of Set 4 | abu zabad
# Processing Record 38 of Set 4 | riyadh
# Processing Record 39 of Set 4 | fougamou
# Processing Record 40 of Set 4 | tuatapere
# Processing Record 41 of Set 4 | college
# Processing Record 42 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 43 of Set 4 | minsk
# Processing Record 44 of Set 4 | le port
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 4 | fare
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | praia da vitoria
# Processing Record 4 of Set 5 | mnogovershinnyy
# Processing Record 5 of Set 5 | krasnoarmeysk
# Processing Record 6 of Set 5 | indramayu
# Processing Record 7 of Set 5 | caravelas
# Processing Record 8 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 9 of Set 5 | ilulissat
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | tendukheda
# Processing Record 12 of Set 5 | farah
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | lima
# Processing Record 15 of Set 5 | abalak
# Processing Record 16 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 17 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 5 | bucine
# Processing Record 19 of Set 5 | ilek
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | mezen
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | placido de castro
# Processing Record 25 of Set 5 | bengkulu
# Processing Record 26 of Set 5 | saint-augustin
# Processing Record 27 of Set 5 | rio verde de mato grosso
# Processing Record 28 of Set 5 | omboue
# Processing Record 29 of Set 5 | adjumani
# Processing Record 30 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 5 | araouane
# Processing Record 32 of Set 5 | bowling green
# Processing Record 33 of Set 5 | vangaindrano
# Processing Record 34 of Set 5 | sao felix do xingu
# Processing Record 35 of Set 5 | comodoro rivadavia
# Processing Record 36 of Set 5 | port-cartier
# Processing Record 37 of Set 5 | hondo
# Processing Record 38 of Set 5 | saskylakh
# Processing Record 39 of Set 5 | maragogi
# Processing Record 40 of Set 5 | airai
# Processing Record 41 of Set 5 | ciudad bolivar
# Processing Record 42 of Set 5 | port hedland
# Processing Record 43 of Set 5 | kaili
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | sinjar
# Processing Record 47 of Set 5 | mahibadhoo
# Processing Record 48 of Set 5 | san mateo ixtatan
# Processing Record 49 of Set 5 | kralendijk
# Processing Record 50 of Set 5 | berlin
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | praia
# Processing Record 4 of Set 6 | magway
# Processing Record 5 of Set 6 | carnarvon
# Processing Record 6 of Set 6 | noumea
# Processing Record 7 of Set 6 | tateyama
# Processing Record 8 of Set 6 | esqueda
# Processing Record 9 of Set 6 | rio grande
# Processing Record 10 of Set 6 | tevaitoa
# Processing Record 11 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 6 | tiksi
# Processing Record 13 of Set 6 | sinop
# Processing Record 14 of Set 6 | little current
# Processing Record 15 of Set 6 | jumla
# Processing Record 16 of Set 6 | mayumba
# Processing Record 17 of Set 6 | lazaro cardenas
# Processing Record 18 of Set 6 | amol
# Processing Record 19 of Set 6 | barberton
# Processing Record 20 of Set 6 | mizdah
# Processing Record 21 of Set 6 | campina grande do sul
# Processing Record 22 of Set 6 | ketchikan
# Processing Record 23 of Set 6 | yusva
# City not found. Skipping...
# Processing Record 24 of Set 6 | salinopolis
# Processing Record 25 of Set 6 | vostok
# Processing Record 26 of Set 6 | iquitos
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | kamenka
# Processing Record 29 of Set 6 | nouakchott
# Processing Record 30 of Set 6 | sao miguel do araguaia
# Processing Record 31 of Set 6 | coahuayana
# Processing Record 32 of Set 6 | nizwa
# Processing Record 33 of Set 6 | tonekabon
# Processing Record 34 of Set 6 | bambous virieux
# Processing Record 35 of Set 6 | port moresby
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | camana
# Processing Record 38 of Set 6 | klaksvik
# Processing Record 39 of Set 6 | gladstone
# Processing Record 40 of Set 6 | passo de camaragibe
# Processing Record 41 of Set 6 | livingston
# Processing Record 42 of Set 6 | karpathos
# Processing Record 43 of Set 6 | narsaq
# Processing Record 44 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 45 of Set 6 | aquiraz
# Processing Record 46 of Set 6 | leh
# Processing Record 47 of Set 6 | thessalon
# Processing Record 48 of Set 6 | pop
# Processing Record 49 of Set 6 | manyana
# Processing Record 50 of Set 6 | rameshki
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | sukhobezvodnoye
# Processing Record 3 of Set 7 | aguimes
# Processing Record 4 of Set 7 | aasiaat
# Processing Record 5 of Set 7 | baruun-urt
# Processing Record 6 of Set 7 | fort nelson
# Processing Record 7 of Set 7 | okha
# Processing Record 8 of Set 7 | koungou
# Processing Record 9 of Set 7 | fomento
# Processing Record 10 of Set 7 | andijon
# Processing Record 11 of Set 7 | belmonte
# Processing Record 12 of Set 7 | okhotsk
# Processing Record 13 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 7 | kaka
# Processing Record 15 of Set 7 | celestun
# Processing Record 16 of Set 7 | nouadhibou
# Processing Record 17 of Set 7 | severo-kurilsk
# Processing Record 18 of Set 7 | adrar
# Processing Record 19 of Set 7 | high level
# Processing Record 20 of Set 7 | chernyshevskiy
# Processing Record 21 of Set 7 | taonan
# Processing Record 22 of Set 7 | henderson
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | voh
# Processing Record 25 of Set 7 | turek
# Processing Record 26 of Set 7 | vardo
# Processing Record 27 of Set 7 | awbari
# Processing Record 28 of Set 7 | port hardy
# Processing Record 29 of Set 7 | banda aceh
# Processing Record 30 of Set 7 | mayo
# Processing Record 31 of Set 7 | lompoc
# Processing Record 32 of Set 7 | shwebo
# Processing Record 33 of Set 7 | warangal
# Processing Record 34 of Set 7 | namatanai
# Processing Record 35 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 7 | alice springs
# Processing Record 37 of Set 7 | tynda
# Processing Record 38 of Set 7 | la ronge
# Processing Record 39 of Set 7 | lata
# Processing Record 40 of Set 7 | khani
# Processing Record 41 of Set 7 | aljezur
# Processing Record 42 of Set 7 | comrie
# Processing Record 43 of Set 7 | paita
# Processing Record 44 of Set 7 | dicabisagan
# Processing Record 45 of Set 7 | krasnyy yar
# Processing Record 46 of Set 7 | hambantota
# Processing Record 47 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 7 | gamboula
# Processing Record 49 of Set 7 | puerto del rosario
# Processing Record 50 of Set 7 | zbiroh
# Processing Record 1 of Set 8 | nioki
# Processing Record 2 of Set 8 | kambove
# Processing Record 3 of Set 8 | mwene-ditu
# Processing Record 4 of Set 8 | abu samrah
# Processing Record 5 of Set 8 | auki
# Processing Record 6 of Set 8 | teya
# Processing Record 7 of Set 8 | irpa irpa
# Processing Record 8 of Set 8 | kupang
# Processing Record 9 of Set 8 | olafsvik
# Processing Record 10 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 8 | gornyatskiy
# Processing Record 12 of Set 8 | salinas
# Processing Record 13 of Set 8 | george town
# Processing Record 14 of Set 8 | fallon
# Processing Record 15 of Set 8 | meulaboh
# Processing Record 16 of Set 8 | luganville
# Processing Record 17 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 18 of Set 8 | olinda
# Processing Record 19 of Set 8 | pangnirtung
# Processing Record 20 of Set 8 | dabakala
# Processing Record 21 of Set 8 | amga
# Processing Record 22 of Set 8 | kurilsk
# Processing Record 23 of Set 8 | saint-francois
# Processing Record 24 of Set 8 | comarapa
# Processing Record 25 of Set 8 | hanzhong
# Processing Record 26 of Set 8 | altamira
# Processing Record 27 of Set 8 | hobyo
# Processing Record 28 of Set 8 | codrington
# Processing Record 29 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 31 of Set 8 | barrhead
# Processing Record 32 of Set 8 | lahaina
# Processing Record 33 of Set 8 | katsuura
# Processing Record 34 of Set 8 | athabasca
# Processing Record 35 of Set 8 | kokopo
# Processing Record 36 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 8 | nazret
# Processing Record 38 of Set 8 | obo
# Processing Record 39 of Set 8 | itarema
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | adeje
# Processing Record 42 of Set 8 | guadalupe victoria
# Processing Record 43 of Set 8 | akyab
# Processing Record 44 of Set 8 | la rioja
# Processing Record 45 of Set 8 | were ilu
# Processing Record 46 of Set 8 | necochea
# Processing Record 47 of Set 8 | lusambo
# Processing Record 48 of Set 8 | qasigiannguit
# Processing Record 49 of Set 8 | hervey bay
# Processing Record 50 of Set 8 | lodja
# Processing Record 1 of Set 9 | jose bonifacio
# Processing Record 2 of Set 9 | sal rei
# Processing Record 3 of Set 9 | broken hill
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | cerknica
# Processing Record 6 of Set 9 | kintampo
# Processing Record 7 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 9 | zyryanka
# Processing Record 9 of Set 9 | sola
# Processing Record 10 of Set 9 | sobolevo
# Processing Record 11 of Set 9 | kutiyana
# Processing Record 12 of Set 9 | vagur
# Processing Record 13 of Set 9 | boyolangu
# Processing Record 14 of Set 9 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 15 of Set 9 | gushikawa
# Processing Record 16 of Set 9 | redmond
# Processing Record 17 of Set 9 | amapa
# Processing Record 18 of Set 9 | bembereke
# Processing Record 19 of Set 9 | mattru
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | camacha
# Processing Record 22 of Set 9 | seymchan
# Processing Record 23 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 9 | luorong
# Processing Record 26 of Set 9 | mareeba
# Processing Record 27 of Set 9 | coolum beach
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | cabo san lucas
# Processing Record 30 of Set 9 | gazli
# Processing Record 31 of Set 9 | dwarka
# Processing Record 32 of Set 9 | romny
# Processing Record 33 of Set 9 | heihe
# Processing Record 34 of Set 9 | norrtalje
# Processing Record 35 of Set 9 | hermosillo
# Processing Record 36 of Set 9 | natal
# Processing Record 37 of Set 9 | srednekolymsk
# Processing Record 38 of Set 9 | hay river
# Processing Record 39 of Set 9 | forssa
# Processing Record 40 of Set 9 | urumqi
# Processing Record 41 of Set 9 | ahipara
# Processing Record 42 of Set 9 | ganzhou
# Processing Record 43 of Set 9 | emerald
# Processing Record 44 of Set 9 | port macquarie
# Processing Record 45 of Set 9 | saint-georges
# Processing Record 46 of Set 9 | ostersund
# Processing Record 47 of Set 9 | dzaoudzi
# Processing Record 48 of Set 9 | brae
# Processing Record 49 of Set 9 | sisimiut
# Processing Record 50 of Set 9 | evanston
# Processing Record 1 of Set 10 | salym
# Processing Record 2 of Set 10 | carmo do paranaiba
# Processing Record 3 of Set 10 | san carlos
# Processing Record 4 of Set 10 | muros
# Processing Record 5 of Set 10 | tazovskiy
# Processing Record 6 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 10 | nyurba
# Processing Record 8 of Set 10 | trelew
# Processing Record 9 of Set 10 | ruwi
# Processing Record 10 of Set 10 | oriximina
# Processing Record 11 of Set 10 | arona
# Processing Record 12 of Set 10 | talas
# Processing Record 13 of Set 10 | otofuke
# Processing Record 14 of Set 10 | komsomolskiy
# Processing Record 15 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 10 | pangkalanbuun
# Processing Record 18 of Set 10 | dalby
# Processing Record 19 of Set 10 | da nang
# Processing Record 20 of Set 10 | aquidaba
# Processing Record 21 of Set 10 | bambanglipuro
# Processing Record 22 of Set 10 | kenai
# Processing Record 23 of Set 10 | raudeberg
# Processing Record 24 of Set 10 | tacna
# Processing Record 25 of Set 10 | lagoa
# Processing Record 26 of Set 10 | benguela
# Processing Record 27 of Set 10 | tommot
# Processing Record 28 of Set 10 | lae
# Processing Record 29 of Set 10 | labuhan
# Processing Record 30 of Set 10 | ketou
# Processing Record 31 of Set 10 | sabang
# Processing Record 32 of Set 10 | te anau
# Processing Record 33 of Set 10 | pavilosta
# Processing Record 34 of Set 10 | daru
# Processing Record 35 of Set 10 | kruisfontein
# Processing Record 36 of Set 10 | yenagoa
# Processing Record 37 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 38 of Set 10 | ambulu
# Processing Record 39 of Set 10 | adre
# Processing Record 40 of Set 10 | esna
# Processing Record 41 of Set 10 | khandbari
# Processing Record 42 of Set 10 | havoysund
# Processing Record 43 of Set 10 | yeppoon
# Processing Record 44 of Set 10 | moses lake
# Processing Record 45 of Set 10 | dingle
# Processing Record 46 of Set 10 | panjab
# Processing Record 47 of Set 10 | torrijos
# Processing Record 48 of Set 10 | mier
# Processing Record 49 of Set 10 | whitehorse
# Processing Record 50 of Set 10 | bitung
# Processing Record 1 of Set 11 | santa fe
# Processing Record 2 of Set 11 | ksenyevka
# City not found. Skipping...
# Processing Record 3 of Set 11 | kartaly
# Processing Record 4 of Set 11 | casas grandes
# Processing Record 5 of Set 11 | nizhniy kuranakh
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | kudymkar
# Processing Record 8 of Set 11 | pauini
# Processing Record 9 of Set 11 | stony mountain
# Processing Record 10 of Set 11 | kiunga
# Processing Record 11 of Set 11 | ahuimanu
# Processing Record 12 of Set 11 | perni
# Processing Record 13 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 11 | severomuysk
# Processing Record 15 of Set 11 | pangai
# Processing Record 16 of Set 11 | pravia
# Processing Record 17 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 18 of Set 11 | haines junction
# Processing Record 19 of Set 11 | denpasar
# Processing Record 20 of Set 11 | wanning
# Processing Record 21 of Set 11 | san juan del sur
# Processing Record 22 of Set 11 | mutis
# Processing Record 23 of Set 11 | tiarei
# Processing Record 24 of Set 11 | huallanca
# Processing Record 25 of Set 11 | cairns
# Processing Record 26 of Set 11 | portage
# Processing Record 27 of Set 11 | mugur-aksy
# Processing Record 28 of Set 11 | aranjuez
# Processing Record 29 of Set 11 | znamenskoye
# Processing Record 30 of Set 11 | ialibu
# Processing Record 31 of Set 11 | bushenyi
# Processing Record 32 of Set 11 | makakilo city
# Processing Record 33 of Set 11 | tigre
# Processing Record 34 of Set 11 | egvekinot
# Processing Record 35 of Set 11 | alice town
# Processing Record 36 of Set 11 | liusha
# Processing Record 37 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 11 | arlit
# Processing Record 39 of Set 11 | whyalla
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | wawa
# Processing Record 42 of Set 11 | amazar
# Processing Record 43 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 11 | honiara
# Processing Record 45 of Set 11 | muscat
# Processing Record 46 of Set 11 | rawson
# Processing Record 47 of Set 11 | sao joao da barra
# Processing Record 48 of Set 11 | mount gambier
# Processing Record 49 of Set 11 | kirando
# Processing Record 50 of Set 11 | usinsk
# Processing Record 1 of Set 12 | cap malheureux
# Processing Record 2 of Set 12 | borzya
# Processing Record 3 of Set 12 | tambul
# City not found. Skipping...
# Processing Record 4 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 12 | matagami
# Processing Record 6 of Set 12 | mitu
# Processing Record 7 of Set 12 | kochevo
# Processing Record 8 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 10 of Set 12 | ploemeur
# Processing Record 11 of Set 12 | calolbon
# Processing Record 12 of Set 12 | palmer
# Processing Record 13 of Set 12 | binghamton
# Processing Record 14 of Set 12 | northam
# Processing Record 15 of Set 12 | boguchany
# Processing Record 16 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 12 | piranhas
# Processing Record 18 of Set 12 | fonte boa
# Processing Record 19 of Set 12 | sinjah
# City not found. Skipping...
# Processing Record 20 of Set 12 | muisne
# Processing Record 21 of Set 12 | bodden town
# Processing Record 22 of Set 12 | domoni
# Processing Record 23 of Set 12 | bongandanga
# Processing Record 24 of Set 12 | helena
# Processing Record 25 of Set 12 | mumbwa
# Processing Record 26 of Set 12 | sturgeon falls
# Processing Record 27 of Set 12 | chumikan
# Processing Record 28 of Set 12 | bilibino
# Processing Record 29 of Set 12 | san policarpo
# Processing Record 30 of Set 12 | shirochanka
# Processing Record 31 of Set 12 | corrente
# Processing Record 32 of Set 12 | karachi
# Processing Record 33 of Set 12 | chaiyaphum
# Processing Record 34 of Set 12 | walvis bay
# Processing Record 35 of Set 12 | palma di montechiaro
# Processing Record 36 of Set 12 | north bend
# Processing Record 37 of Set 12 | meadow lake
# Processing Record 38 of Set 12 | ocos
# Processing Record 39 of Set 12 | syracuse
# Processing Record 40 of Set 12 | alim
# Processing Record 41 of Set 12 | kamaishi
# Processing Record 42 of Set 12 | kibungo
# Processing Record 43 of Set 12 | mosquera
# Processing Record 44 of Set 12 | isangel
# Processing Record 45 of Set 12 | tulare
# Processing Record 46 of Set 12 | tocantins
# Processing Record 47 of Set 12 | the pas
# Processing Record 48 of Set 12 | wewak
# Processing Record 49 of Set 12 | dadri
# Processing Record 50 of Set 12 | minuri
# Processing Record 1 of Set 13 | astana
# Processing Record 2 of Set 13 | sobrance
# Processing Record 3 of Set 13 | burica
# City not found. Skipping...
# Processing Record 4 of Set 13 | waingapu
# Processing Record 5 of Set 13 | benghazi
# Processing Record 6 of Set 13 | angoram
# Processing Record 7 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 8 of Set 13 | ulaanbaatar
# Processing Record 9 of Set 13 | salalah
# Processing Record 10 of Set 13 | santo tomas
# Processing Record 11 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 13 | mogocha
# Processing Record 13 of Set 13 | leningradskiy
# Processing Record 14 of Set 13 | pyapon
# Processing Record 15 of Set 13 | tiruvottiyur
# City not found. Skipping...
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | buraydah
# Processing Record 18 of Set 13 | caidian
# Processing Record 19 of Set 13 | presidente olegario
# Processing Record 20 of Set 13 | madaripur
# Processing Record 21 of Set 13 | mananjary
# Processing Record 22 of Set 13 | ojinaga
# Processing Record 23 of Set 13 | puqi
# Processing Record 24 of Set 13 | flinders
# Processing Record 25 of Set 13 | kupino
# Processing Record 26 of Set 13 | anadyr
# Processing Record 27 of Set 13 | eureka
# Processing Record 28 of Set 13 | puerto baquerizo moreno
# Processing Record 29 of Set 13 | touros
# Processing Record 30 of Set 13 | phultala
# Processing Record 31 of Set 13 | makung
# City not found. Skipping...
# Processing Record 32 of Set 13 | foggia
# Processing Record 33 of Set 13 | dukat
# Processing Record 34 of Set 13 | bubaque
# Processing Record 35 of Set 13 | naze
# Processing Record 36 of Set 13 | goundam
# Processing Record 37 of Set 13 | nyrob
# Processing Record 38 of Set 13 | yuci
# Processing Record 39 of Set 13 | vidim
# Processing Record 40 of Set 13 | kasane
# Processing Record 41 of Set 13 | oron
# Processing Record 42 of Set 13 | saint-denis
# Processing Record 43 of Set 13 | tigil
# Processing Record 44 of Set 13 | lumberton
# Processing Record 45 of Set 13 | mauganj
# Processing Record 46 of Set 13 | bontang
# Processing Record 47 of Set 13 | santa rosa
# Processing Record 48 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 13 | nautla
# Processing Record 50 of Set 13 | karratha
# Processing Record 1 of Set 14 | rafaela
# Processing Record 2 of Set 14 | petawawa
# Processing Record 3 of Set 14 | los llanos de aridane
# Processing Record 4 of Set 14 | lhokseumawe
# Processing Record 5 of Set 14 | shizuishan
# Processing Record 6 of Set 14 | pilot butte
# Processing Record 7 of Set 14 | byron bay
# Processing Record 8 of Set 14 | lunino
# Processing Record 9 of Set 14 | the valley
# Processing Record 10 of Set 14 | vestmanna
# Processing Record 11 of Set 14 | dolores
# Processing Record 12 of Set 14 | taloda
# Processing Record 13 of Set 14 | prince rupert
# Processing Record 14 of Set 14 | mogadishu
# Processing Record 15 of Set 14 | shelburne
# Processing Record 16 of Set 14 | manzanillo
# Processing Record 17 of Set 14 | mantua
# Processing Record 18 of Set 14 | nelson bay
# Processing Record 19 of Set 14 | port lincoln
# Processing Record 20 of Set 14 | saint-paul
# Processing Record 21 of Set 14 | tarauaca
# Processing Record 22 of Set 14 | kapoeta
# Processing Record 23 of Set 14 | taltal
# Processing Record 24 of Set 14 | isla vista
# Processing Record 25 of Set 14 | grants
# Processing Record 26 of Set 14 | ca mau
# Processing Record 27 of Set 14 | staunton
# Processing Record 28 of Set 14 | remedios
# Processing Record 29 of Set 14 | izazi
# Processing Record 30 of Set 14 | anloga
# Processing Record 31 of Set 14 | tecpan
# Processing Record 32 of Set 14 | tutla
# City not found. Skipping...
# Processing Record 33 of Set 14 | orizona
# Processing Record 34 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 35 of Set 14 | beipiao
# Processing Record 36 of Set 14 | tondano
# Processing Record 37 of Set 14 | yerbogachen
# Processing Record 38 of Set 14 | anamur
# Processing Record 39 of Set 14 | ulladulla
# Processing Record 40 of Set 14 | benxi
# Processing Record 41 of Set 14 | diffa
# Processing Record 42 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 43 of Set 14 | canora
# Processing Record 44 of Set 14 | ust-kuyga
# Processing Record 45 of Set 14 | camocim
# Processing Record 46 of Set 14 | russell
# Processing Record 47 of Set 14 | quatre cocos
# Processing Record 48 of Set 14 | ishlei
# City not found. Skipping...
# Processing Record 49 of Set 14 | coihaique
# Processing Record 50 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 1 of Set 15 | mersing
# Processing Record 2 of Set 15 | touliu
# City not found. Skipping...
# Processing Record 3 of Set 15 | brasilia de minas
# Processing Record 4 of Set 15 | tiverton
# Processing Record 5 of Set 15 | volgodonsk
# Processing Record 6 of Set 15 | de-kastri
# Processing Record 7 of Set 15 | cajazeiras
# Processing Record 8 of Set 15 | esso
# Processing Record 9 of Set 15 | kotri
# Processing Record 10 of Set 15 | werda
# Processing Record 11 of Set 15 | barra
# Processing Record 12 of Set 15 | akhmeta
# Processing Record 13 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 14 of Set 15 | sahbuz
# Processing Record 15 of Set 15 | itaituba
# Processing Record 16 of Set 15 | novotroitsk
# Processing Record 17 of Set 15 | vengerovo
# Processing Record 18 of Set 15 | kyzyl-mazhalyk
# Processing Record 19 of Set 15 | wad madani
# Processing Record 20 of Set 15 | tura
# Processing Record 21 of Set 15 | urengoy
# Processing Record 22 of Set 15 | faya
# Processing Record 23 of Set 15 | pecos
# Processing Record 24 of Set 15 | nicoya
# Processing Record 25 of Set 15 | poum
# Processing Record 26 of Set 15 | talakan
# Processing Record 27 of Set 15 | barcelona
# Processing Record 28 of Set 15 | puerto maldonado
# Processing Record 29 of Set 15 | cabra
# Processing Record 30 of Set 15 | ayr
# Processing Record 31 of Set 15 | agudos
# Processing Record 32 of Set 15 | behbahan
# Processing Record 33 of Set 15 | kifri
# Processing Record 34 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 15 | riacho de santana
# Processing Record 36 of Set 15 | cayenne
# Processing Record 37 of Set 15 | exeter
# Processing Record 38 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 39 of Set 15 | assai
# Processing Record 40 of Set 15 | acajutla
# Processing Record 41 of Set 15 | hohhot
# Processing Record 42 of Set 15 | kahta
# Processing Record 43 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 15 | tamandare
# Processing Record 45 of Set 15 | liling
# Processing Record 46 of Set 15 | athens
# Processing Record 47 of Set 15 | trinidad
# Processing Record 48 of Set 15 | panji
# Processing Record 49 of Set 15 | san francisco
# Processing Record 50 of Set 15 | temizhbekskaya
# Processing Record 1 of Set 16 | henties bay
# Processing Record 2 of Set 16 | marsh harbour
# Processing Record 3 of Set 16 | ullal
# Processing Record 4 of Set 16 | springville
# Processing Record 5 of Set 16 | kirakira
# ----------------------------
# Data Retieval Complete
# ----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Nikolskoye  59.70   30.79     43.00        93          90        6.71
# 1  Puerto Ayora  -0.74  -90.35     68.00        86          70        5.99
# 2       Agirish  61.92   63.02     24.71        98         100        4.18
# 3        Faanui -16.48 -151.75     80.74        68          34        7.14
# 4       Rikitea -23.12 -134.97     74.71        80         100       23.55
#
#   Country Current Description
# 0      RU     overcast clouds
# 1      EC       broken clouds
# 2      RU     overcast clouds
# 3      PF    scattered clouds
# 4      PF          light rain

# %%
# Reorder the columns of the DataFrame.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head()
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nikolskoye      RU  59.70   30.79     43.00        93          90
# 1  Puerto Ayora      EC  -0.74  -90.35     68.00        86          70
# 2       Agirish      RU  61.92   63.02     24.71        98         100
# 3        Faanui      PF -16.48 -151.75     80.74        68          34
# 4       Rikitea      PF -23.12 -134.97     74.71        80         100
#
#    Wind Speed Current Description
# 0        6.71     overcast clouds
# 1        5.99       broken clouds
# 2        4.18     overcast clouds
# 3        7.14    scattered clouds
# 4       23.55          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data into a csv.
city_data_df.to_csv(output_data_file, index_label="City_ID")
